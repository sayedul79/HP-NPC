# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print('All essential libeary are imported')
# Out:
# All essential libeary are imported

# %%
plt.style.use('fivethirtyeight')

# %%
np.ma
x=np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
plt.figure() # create a plot figure
# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))
# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
fig=plt.figure()
ax=plt.axes()

# %%
fig=plt.figure()
ax=plt.axes()
x=np.linspace(0,10,100)
ax.plot(x, np.sin(x))
plt.show()

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();

# %%
ax=plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0,10), ylim=(-1.3,1.3), xlabel='x',
      ylabel='sin(x)', title='sample plot')
# Out:
# [(0.0, 10.0),
#  (-1.3, 1.3),
#  Text(0.5, 0, 'x'),
#  Text(0, 0.5, 'sin(x)'),
#  Text(0.5, 1.0, 'sample plot')]

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
cmap='viridis')

# %%
print(x)
# Out:
# [ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799 -0.97727788
#   0.95008842 -0.15135721 -0.10321885  0.4105985   0.14404357  1.45427351
#   0.76103773  0.12167502  0.44386323  0.33367433  1.49407907 -0.20515826
#   0.3130677  -0.85409574 -2.55298982  0.6536186   0.8644362  -0.74216502
#   2.26975462 -1.45436567  0.04575852 -0.18718385  1.53277921  1.46935877
#   0.15494743  0.37816252 -0.88778575 -1.98079647 -0.34791215  0.15634897
#   1.23029068  1.20237985 -0.38732682 -0.30230275 -1.04855297 -1.42001794
#  -1.70627019  1.9507754  -0.50965218 -0.4380743  -1.25279536  0.77749036
#  -1.61389785 -0.21274028 -0.89546656  0.3869025  -0.51080514 -1.18063218
#  -0.02818223  0.42833187  0.06651722  0.3024719  -0.63432209 -0.36274117
#  -0.67246045 -0.35955316 -0.81314628 -1.7262826   0.17742614 -0.40178094
#  -1.63019835  0.46278226 -0.90729836  0.0519454   0.72909056  0.12898291
#   1.13940068 -1.23482582  0.40234164 -0.68481009 -0.87079715 -0.57884966
# ...

# %%
colors
# Out:
# array([0.96193638, 0.29214753, 0.24082878, 0.10029394, 0.01642963,
#        0.92952932, 0.66991655, 0.78515291, 0.28173011, 0.58641017,
#        0.06395527, 0.4856276 , 0.97749514, 0.87650525, 0.33815895,
#        0.96157015, 0.23170163, 0.94931882, 0.9413777 , 0.79920259,
#        0.63044794, 0.87428797, 0.29302028, 0.84894356, 0.61787669,
#        0.01323686, 0.34723352, 0.14814086, 0.98182939, 0.47837031,
#        0.49739137, 0.63947252, 0.36858461, 0.13690027, 0.82211773,
#        0.18984791, 0.51131898, 0.22431703, 0.09784448, 0.86219152,
#        0.97291949, 0.96083466, 0.9065555 , 0.77404733, 0.33314515,
#        0.08110139, 0.40724117, 0.23223414, 0.13248763, 0.05342718,
#        0.72559436, 0.01142746, 0.77058075, 0.14694665, 0.07952208,
#        0.08960303, 0.67204781, 0.24536721, 0.42053947, 0.55736879,
#        0.86055117, 0.72704426, 0.27032791, 0.1314828 , 0.05537432,
#        0.30159863, 0.26211815, 0.45614057, 0.68328134, 0.69562545,
# ...

# %%
data=np.random.randn(10000)
plt.hist(data)
# Out:
# (array([3.700e+01, 2.480e+02, 1.131e+03, 2.304e+03, 3.092e+03, 2.125e+03,
#         8.450e+02, 1.950e+02, 2.100e+01, 2.000e+00]),
#  array([-3.4750907 , -2.68998024, -1.90486978, -1.11975931, -0.33464885,
#          0.45046161,  1.23557207,  2.02068253,  2.80579299,  3.59090345,
#          4.37601392]),
#  <BarContainer object of 10 artists>)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#plt.style.use('dark_background')
plt.hist(data)
# Out:
# (array([3.700e+01, 2.480e+02, 1.131e+03, 2.304e+03, 3.092e+03, 2.125e+03,
#         8.450e+02, 1.950e+02, 2.100e+01, 2.000e+00]),
#  array([-3.4750907 , -2.68998024, -1.90486978, -1.11975931, -0.33464885,
#          0.45046161,  1.23557207,  2.02068253,  2.80579299,  3.59090345,
#          4.37601392]),
#  <BarContainer object of 10 artists>)

# %%
plt.style.use('seaborn-notebook')
plt.hist(data)
# Out:
# (array([3.700e+01, 2.480e+02, 1.131e+03, 2.304e+03, 3.092e+03, 2.125e+03,
#         8.450e+02, 1.950e+02, 2.100e+01, 2.000e+00]),
#  array([-3.4750907 , -2.68998024, -1.90486978, -1.11975931, -0.33464885,
#          0.45046161,  1.23557207,  2.02068253,  2.80579299,  3.59090345,
#          4.37601392]),
#  <BarContainer object of 10 artists>)

# %%
plt.style.use('fivethirtyeight')

# %%
plt.hist(data)
# Out:
# (array([3.700e+01, 2.480e+02, 1.131e+03, 2.304e+03, 3.092e+03, 2.125e+03,
#         8.450e+02, 1.950e+02, 2.100e+01, 2.000e+00]),
#  array([-3.4750907 , -2.68998024, -1.90486978, -1.11975931, -0.33464885,
#          0.45046161,  1.23557207,  2.02068253,  2.80579299,  3.59090345,
#          4.37601392]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins=30, density=None, alpha=1.0,
histtype='bar', color='seagreen',
edgecolor='black');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.2, density=True, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([0.00574934, 0.00574934, 0.00862401, 0.01437335, 0.00574934,
#         0.01724802, 0.02299737, 0.03737072, 0.06611743, 0.08336545,
#         0.07474144, 0.11498683, 0.13223486, 0.1667309 , 0.15523222,
#         0.19547761, 0.17822959, 0.20985097, 0.18397893, 0.18397893,
#         0.16960558, 0.16098156, 0.14948288, 0.12073617, 0.1178615 ,
#         0.08911479, 0.04599473, 0.0488694 , 0.0201227 , 0.02874671,
#         0.02587204, 0.02299737, 0.        , 0.00862401, 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.00287467]),
#  array([-3.09487909, -2.74701317, -2.39914725, -2.05128133, -1.7034154 ,
#         -1.35554948, -1.00768356, -0.65981764, -0.31195171,  0.03591421,
#          0.38378013,  0.73164605,  1.07951197,  1.4273779 ,  1.77524382,
#          2.12310974,  2.47097566,  2.81884158,  3.16670751,  3.51457343,
#          3.86243935,  4.21030527,  4.55817119,  4.90603712,  5.25390304,
# ...

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [ 285 3435 5217 1040   23]

# %% [markdown]
# # Customizing Plot Legends

# %%
x=np.linspace(0,10,1000)
fig,ax=plt.subplots()
ax.plot(x, np.sin(x), label='sine')
ax.plot(x, np.cos(x), label='cosine')
ax.axis('equal')
ax.legend(loc='upper left', frameon=False)

# %%
ax.legend(frameon=False, loc='upper center', ncol=2)
fig

# %%
ax.legend(shadow=True, loc='upper left')
fig
