# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
df=pd.read_table('Music/gapminder.tsv')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.331999999999997, 9240934,
#         820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.1007099999999],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499602999999],
#        ['Zimbabwe', 'Africa', 2002, 39.989000000000004, 11926563,
#         672.0386227000001],
#        ['Zimbabwe', 'Africa', 2007, 43.486999999999995, 12311143,
#         469.70929810000007]], dtype=object)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
country_df=df['country']
country_df.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
type(country_df)
# Out:
# pandas.core.series.Series

# %%
subset=df[['country', 'continent', 'year']]
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
df.loc[2]
# Out:
# country      Afghanistan
# continent           Asia
# year                1962
# lifeExp           31.997
# pop             10267083
# gdpPercap        853.101
# Name: 2, dtype: object

# %% [markdown]
# # indexing

# %%
df.loc[2:6]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439

# %%
df.iloc[2]
# Out:
# country      Afghanistan
# continent           Asia
# year                1962
# lifeExp           31.997
# pop             10267083
# gdpPercap        853.101
# Name: 2, dtype: object

# %%
subset=df.loc[:, ['year', 'pop']]
subset.head()
# Out:
#    year       pop
# 0  1952   8425333
# 1  1957   9240934
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460

# %%
df.loc[df.year==1967, ['year', 'pop']]
# Out:
#       year       pop
# 3     1967  11537966
# 15    1967   1984060
# 27    1967  12760499
# 39    1967   5247469
# 51    1967  22934225
# ...    ...       ...
# 1647  1967  39463910
# 1659  1967   1142636
# 1671  1967   6740785
# 1683  1967   3900000
# 1695  1967   4995432
#
# [142 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# country      0
# continent    0
# year         0
# lifeExp      0
# pop          0
# gdpPercap    0
# dtype: int64

# %%
bangladesh=df.loc[df.country=='Bangladesh', :]
bangladesh
# Out:
#         country continent  year  lifeExp        pop    gdpPercap
# 96   Bangladesh      Asia  1952   37.484   46886859   684.244172
# 97   Bangladesh      Asia  1957   39.348   51365468   661.637458
# 98   Bangladesh      Asia  1962   41.216   56839289   686.341554
# 99   Bangladesh      Asia  1967   43.453   62821884   721.186086
# 100  Bangladesh      Asia  1972   45.252   70759295   630.233627
# 101  Bangladesh      Asia  1977   46.923   80428306   659.877232
# 102  Bangladesh      Asia  1982   50.009   93074406   676.981866
# 103  Bangladesh      Asia  1987   52.819  103764241   751.979403
# 104  Bangladesh      Asia  1992   56.018  113704579   837.810164
# 105  Bangladesh      Asia  1997   59.412  123315288   972.770035
# 106  Bangladesh      Asia  2002   62.013  135656790  1136.390430
# 107  Bangladesh      Asia  2007   64.062  150448339  1391.253792

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bangladesh.set_index('year')['pop'].plot()

# %%
bangladesh.set_index('year')['lifeExp'].plot()

# %%
bangladesh.set_index('year')['gdpPercap'].plot()

# %%
df.groupby('continent')['pop', 'gdpPercap'].sum()
# Out:
# C:\Users\HP-NPC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                    pop     gdpPercap
# continent
# Africa      6187585961  1.368903e+06
# Americas    7351438499  2.140833e+06
# Asia       30507333901  3.129252e+06
# Europe      6181115304  5.209011e+06
# Oceania      212992136  4.469186e+05

# %%
df.groupby('continent')['pop', 'gdpPercap'].median()['pop'].plot(kind='bar')
# Out:
# C:\Users\HP-NPC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
asia=df.loc[df.continent=='Asia', ['year', 'pop']].set_index('year')
asia
# Out:
#            pop
# year
# 1952   8425333
# 1957   9240934
# 1962  10267083
# 1967  11537966
# 1972  13079460
# ...        ...
# 1987  11219340
# 1992  13367997
# 1997  15826497
# 2002  18701257
# 2007  22211743
#
# [396 rows x 1 columns]

# %%
import numpy as np

# %%
asia.mean()
# Out:
# pop    7.703872e+07
# dtype: float64

# %%
np.log(asia.mean())
# Out:
# pop    18.159819
# dtype: float64

# %%
np.log(asia).tail()
# Out:
#             pop
# year
# 1987  16.233150
# 1992  16.408374
# 1997  16.577196
# 2002  16.744101
# 2007  16.916132

# %%
asia.shape
# Out:
# (396, 1)

# %%
asia.head()
# Out:
#            pop
# year
# 1952   8425333
# 1957   9240934
# 1962  10267083
# 1967  11537966
# 1972  13079460

# %%
df.groupby('continent')['pop', 'gdpPercap'].agg(['max', 'min'])
# Out:
# C:\Users\HP-NPC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                   pop              gdpPercap
#                   max      min           max           min
# continent
# Africa      135031164    60011   21951.21176    241.165877
# Americas    301139947   662850   42951.65309   1201.637154
# Asia       1318683096   120447  113523.13290    331.000000
# Europe       82400996   147962   49357.19017    973.533195
# Oceania      20434176  1994794   34435.36744  10039.595640

# %%
df.groupby('continent')['pop', 'gdpPercap'].describe()
# Out:
# C:\Users\HP-NPC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#              pop                                                     \
#            count          mean           std        min         25%
# continent
# Africa     624.0  9.916003e+06  1.549092e+07    60011.0  1342075.00
# Americas   300.0  2.450479e+07  5.097943e+07   662850.0  2962358.75
# Asia       396.0  7.703872e+07  2.068852e+08   120447.0  3844393.00
# Europe     360.0  1.716976e+07  2.051944e+07   147962.0  4331500.00
# Oceania     24.0  8.874672e+06  6.506342e+06  1994794.0  3199212.50
#
#                                                  gdpPercap                \
#                   50%          75%           max     count          mean
# continent
# Africa      4579311.0  10801489.75  1.350312e+08     624.0   2193.754578
# ...

# %%
df.drop('year', axis=1).corr()
# Out:
#             lifeExp       pop  gdpPercap
# lifeExp    1.000000  0.064955   0.583706
# pop        0.064955  1.000000  -0.025600
# gdpPercap  0.583706 -0.025600   1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(df.drop('year', axis=1).corr(), annot=True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_covid = pd.read_csv('Music/owid-covid-data.csv')
df_covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2019-12-31          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-01          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-02          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-03          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-04          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df=df_covid.loc[df_covid.location=='Bangladesh', :]
df.head()
# Out:
#      iso_code continent    location        date  total_cases  new_cases  \
# 3211      BGD      Asia  Bangladesh  2020-03-04          NaN        NaN
# 3212      BGD      Asia  Bangladesh  2020-03-05          NaN        NaN
# 3213      BGD      Asia  Bangladesh  2020-03-06          NaN        NaN
# 3214      BGD      Asia  Bangladesh  2020-03-07          NaN        NaN
# 3215      BGD      Asia  Bangladesh  2020-03-08          NaN        NaN
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 3211                 NaN           NaN         NaN                  NaN  ...
# 3212                 NaN           NaN         NaN                  NaN  ...
# 3213                 NaN           NaN         NaN                  NaN  ...
# 3214                 NaN           NaN         NaN                  NaN  ...
# 3215                 NaN           NaN         NaN                  NaN  ...
#
# ...

# %%
df.shape
# Out:
# (189, 40)

# %%
df.tail()
# Out:
#      iso_code continent    location        date  total_cases  new_cases  \
# 3395      BGD      Asia  Bangladesh  2020-09-04     319686.0     2158.0
# 3396      BGD      Asia  Bangladesh  2020-09-05     321615.0     1929.0
# 3397      BGD      Asia  Bangladesh  2020-09-06     323565.0     1950.0
# 3398      BGD      Asia  Bangladesh  2020-09-07     325157.0     1592.0
# 3399      BGD      Asia  Bangladesh  2020-09-08     327359.0     2202.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 3395            2157.571        4383.0        32.0               36.571  ...
# 3396            2117.286        4412.0        29.0               34.000  ...
# 3397            2091.429        4447.0        35.0               34.429  ...
# 3398            2047.857        4449.0         2.0               28.714  ...
# 3399            2051.857        4516.0        67.0               33.571  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189 entries, 3211 to 3399
# Data columns (total 40 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         189 non-null    object
#  1   continent                        189 non-null    object
#  2   location                         189 non-null    object
#  3   date                             189 non-null    object
#  4   total_cases                      178 non-null    float64
#  5   new_cases                        178 non-null    float64
#  6   new_cases_smoothed               178 non-null    float64
#  7   total_deaths                     178 non-null    float64
#  8   new_deaths                       178 non-null    float64
#  9   new_deaths_smoothed              178 non-null    float64
#  10  total_cases_per_million          178 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                            0
# continent                           0
# location                            0
# date                                0
# total_cases                        11
# new_cases                          11
# new_cases_smoothed                 11
# total_deaths                       11
# new_deaths                         11
# new_deaths_smoothed                11
# total_cases_per_million            11
# new_cases_per_million              11
# new_cases_smoothed_per_million     11
# total_deaths_per_million           11
# new_deaths_per_million             11
# new_deaths_smoothed_per_million    11
# new_tests                           9
# total_tests                         7
# total_tests_per_thousand            7
# new_tests_per_thousand              9
# new_tests_smoothed                 13
# new_tests_smoothed_per_thousand    13
# tests_per_case                     19
# positive_rate                      18
# tests_units                         6
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy'],
#       dtype='object')

# %%
#cols=['total_cases', 'new_cases',
      # 'total_deaths', 'new_deaths', 'total_cases_per_million',
      #'new_cases_per_million', 'total_deaths_per_million',
      # 'new_deaths_per_million', 'total_tests', 'new_tests',
      # 'total_tests_per_thousand', 'new_tests_per_thousand',
      # 'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
      # 'stringency_index', 'population', 'population_density', 'median_age',
      # 'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
      # 'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
      # 'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
      # 'life_expectancy']

# %%
cols=df.select_dtypes(include='number').columns
cols
# Out:
# Index(['total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'stringency_index', 'population',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy'],
#       dtype='object')

# %%
for i in cols:
    sns.distplot(df[i],kde=False,hist=True,bins=11,hist_kws=dict(edgecolor="k", linewidth=1))
    plt.title("Histogram")
    plt.ylabel("Frequency")
    plt.show()

# %%
l=['new_deaths', 'new_deaths_per_million']
for i in l:
    sns.boxplot(y=i, data=df)
    plt.show()

# %%
df.new_deaths.sum()
# Out:
# 4516.0

# %%
df.new_deaths.nlargest()
# Out:
# 3399    67.0
# 3330    64.0
# 3335    55.0
# 3337    55.0
# 3356    54.0
# Name: new_deaths, dtype: float64

# %%
df.loc[[3399, 3330, 3335]]
# Out:
#      iso_code continent    location        date  total_cases  new_cases  \
# 3399      BGD      Asia  Bangladesh  2020-09-08     327359.0     2202.0
# 3330      BGD      Asia  Bangladesh  2020-07-01     145483.0     3682.0
# 3335      BGD      Asia  Bangladesh  2020-07-06     162417.0     2738.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 3399            2051.857        4516.0        67.0               33.571  ...
# 3330            3755.000        1847.0        64.0               43.143  ...
# 3335            3518.571        2052.0        55.0               44.857  ...
#
#       aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 3399          3.262        3523.984             14.8                298.003
# 3330          3.262        3523.984             14.8                298.003
# 3335          3.262        3523.984             14.8                298.003
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# ...

# %%
cols_2=[ 'new_cases',
       'total_deaths', 'new_deaths', 'total_cases_per_million',
       'new_cases_per_million', 'total_deaths_per_million',
       'new_deaths_per_million', 'total_tests', 'new_tests',
       'total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
       'stringency_index', 'population', 'population_density', 'median_age',
       'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
        'diabetes_prevalence', 'female_smokers',
       'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy']

# %%
for i in cols_2:
    sns.scatterplot(x='total_cases', y=i, data=df)
    plt.show()

# %%
for i in cols_2:
    sns.lineplot(x='total_cases',y=i,data=df)
    plt.title("Line Plots")
    plt.show()

# %%
df['dates']=pd.to_datetime(df.date)
df.dates.head()
# Out:
# C:\Users\HP-NPC\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 3211   2020-03-04
# 3212   2020-03-05
# 3213   2020-03-06
# 3214   2020-03-07
# 3215   2020-03-08
# Name: dates, dtype: datetime64[ns]

# %%
df.dates.dt.month
# Out:
# 3211    3
# 3212    3
# 3213    3
# 3214    3
# 3215    3
#        ..
# 3395    9
# 3396    9
# 3397    9
# 3398    9
# 3399    9
# Name: dates, Length: 189, dtype: int64

# %%
sns.lineplot(x=df.dates, y=df.new_deaths)

# %%
# total new_deaths in every month

df.groupby(df.dates.dt.month).new_deaths.sum()
# Out:
# dates
# 3       5.0
# 4     158.0
# 5     447.0
# 6    1173.0
# 7    1300.0
# 8    1165.0
# 9     268.0
# Name: new_deaths, dtype: float64

# %%
df.groupby(df.dates.dt.month).new_deaths.sum().plot(kind='bar')

# %%
df.groupby(df.dates.dt.month).new_cases.sum()
# Out:
# dates
# 3       49.0
# 4     7054.0
# 5    37505.0
# 6    97193.0
# 7    93088.0
# 8    75933.0
# 9    16537.0
# Name: new_cases, dtype: float64

# %%
df.groupby(df.dates.dt.month).new_cases.sum().plot(kind='bar')

# %%
df.groupby(df.dates.dt.month).new_cases.sum().plot(kind='pie')

# %%
mental=pd.read_csv('Music/mental_health.csv')
mental.head()
# Out:
#                Country  Year  Mental hospitals (per 100 000 population)  \
# 0          Afghanistan  2016                                      0.003
# 1              Albania  2016                                      0.068
# 2              Algeria  2016                                      0.048
# 3               Angola  2016                                      0.011
# 4  Antigua and Barbuda  2016                                      1.001
#
#    Mental health units in general hospitals (per 100 000 population)  \
# 0                                              0.012
# 1                                              0.068
# 2                                              0.068
# 3                                                NaN
# 4                                                NaN
#
#    Mental health outpatient facilities (per 100 000 population)  \
# 0                                              0.006
# 1                                              0.410
# ...

# %%
mental.columns=mental.columns.str.replace(' ', '_')

# %%
mental.tail()
# Out:
#       Country  Year  Mental_hospitals_(per_100_000_population)  \
# 158   Vanuatu  2016                                        NaN
# 159  Viet Nam  2016                                      0.043
# 160     Yemen  2016                                      0.033
# 161    Zambia  2016                                      0.062
# 162  Zimbabwe  2016                                      0.025
#
#      Mental_health_units_in_general_hospitals_(per_100_000_population)  \
# 158                                              0.756
# 159                                              0.017
# 160                                              0.026
# 161                                              0.062
# 162                                              0.025
#
#      Mental_health_outpatient_facilities_(per_100_000_population)  \
# 158                                              2.645
# 159                                              0.009
# 160                                              0.063
# ...

# %%
mental.columns
# Out:
# Index(['Country', 'Year', 'Mental_hospitals_(per_100_000_population)',
#        'Mental_health_units_in_general_hospitals_(per_100_000_population)',
#        'Mental_health_outpatient_facilities_(per_100_000_population)',
#        'Mental_health_day_treatment_facilities_(per_100_000_population)',
#        'Community_residential_facilities_(per_100_000_population)'],
#       dtype='object')

# %%
mental.isnull().sum()
# Out:
# Country                                                               0
# Year                                                                  0
# Mental_hospitals_(per_100_000_population)                            32
# Mental_health_units_in_general_hospitals_(per_100_000_population)    25
# Mental_health_outpatient_facilities_(per_100_000_population)         24
# Mental_health_day_treatment_facilities_(per_100_000_population)      89
# Community_residential_facilities_(per_100_000_population)            98
# dtype: int64

# %%
mental.shape
# Out:
# (163, 7)

# %%
mental.loc[mental['Mental_health_day_treatment_facilities_(per_100_000_population)'].isnull()].head()
# Out:
#                Country  Year  Mental_hospitals_(per_100_000_population)  \
# 0          Afghanistan  2016                                      0.003
# 1              Albania  2016                                      0.068
# 2              Algeria  2016                                      0.048
# 3               Angola  2016                                      0.011
# 4  Antigua and Barbuda  2016                                      1.001
#
#    Mental_health_units_in_general_hospitals_(per_100_000_population)  \
# 0                                              0.012
# 1                                              0.068
# 2                                              0.068
# 3                                                NaN
# 4                                                NaN
#
#    Mental_health_outpatient_facilities_(per_100_000_population)  \
# 0                                              0.006
# 1                                              0.410
# ...

# %%
mental.dtypes
# Out:
# Country                                                               object
# Year                                                                   int64
# Mental_hospitals_(per_100_000_population)                            float64
# Mental_health_units_in_general_hospitals_(per_100_000_population)    float64
# Mental_health_outpatient_facilities_(per_100_000_population)         float64
# Mental_health_day_treatment_facilities_(per_100_000_population)      float64
# Community_residential_facilities_(per_100_000_population)            float64
# dtype: object

# %%
mental.loc[mental.Country=='Bangladesh']
# Out:
#        Country  Year  Mental_hospitals_(per_100_000_population)  \
# 12  Bangladesh  2016                                      0.001
#
#     Mental_health_units_in_general_hospitals_(per_100_000_population)  \
# 12                                              0.035
#
#     Mental_health_outpatient_facilities_(per_100_000_population)  \
# 12                                              0.055
#
#     Mental_health_day_treatment_facilities_(per_100_000_population)  \
# 12                                                NaN
#
#     Community_residential_facilities_(per_100_000_population)
# 12                                              0.045

# %%
mental.isnull().sum()
# Out:
# Country                                                               0
# Year                                                                  0
# Mental_hospitals_(per_100_000_population)                            32
# Mental_health_units_in_general_hospitals_(per_100_000_population)    25
# Mental_health_outpatient_facilities_(per_100_000_population)         24
# Mental_health_day_treatment_facilities_(per_100_000_population)      89
# Community_residential_facilities_(per_100_000_population)            98
# dtype: int64

# %%
df.tail()
# Out:
#      iso_code continent    location        date  total_cases  new_cases  \
# 3395      BGD      Asia  Bangladesh  2020-09-04     319686.0     2158.0
# 3396      BGD      Asia  Bangladesh  2020-09-05     321615.0     1929.0
# 3397      BGD      Asia  Bangladesh  2020-09-06     323565.0     1950.0
# 3398      BGD      Asia  Bangladesh  2020-09-07     325157.0     1592.0
# 3399      BGD      Asia  Bangladesh  2020-09-08     327359.0     2202.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 3395            2157.571        4383.0        32.0               36.571  ...
# 3396            2117.286        4412.0        29.0               34.000  ...
# 3397            2091.429        4447.0        35.0               34.429  ...
# 3398            2047.857        4449.0         2.0               28.714  ...
# 3399            2051.857        4516.0        67.0               33.571  ...
#
#       gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df_pop=pd.read_table('Music/gapminder.tsv')
df_pop.head(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710

# %%
df_pop.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df_bd=df_pop.loc[df_pop.country=='Bangladesh']
df_bd.shape
# Out:
# (12, 6)

# %%
df_bd.head()
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 96   Bangladesh      Asia  1952   37.484  46886859  684.244172
# 97   Bangladesh      Asia  1957   39.348  51365468  661.637458
# 98   Bangladesh      Asia  1962   41.216  56839289  686.341554
# 99   Bangladesh      Asia  1967   43.453  62821884  721.186086
# 100  Bangladesh      Asia  1972   45.252  70759295  630.233627

# %%
# %matplotlib inline

# %%
df_bd.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-50999f7c967d> in <module>
# ----> 1 df_bd.types
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
df_bd.describe()

# %%
df_bd.head()

# %%
df_bd.gdpPercap.plot(kind='bar')

# %%
df_bd.lifeExp.plot(kind='bar')

# %%
df_bd['pop'].plot(kind='bar')
