# %%
import pandas as pd
df=pd.read_csv('D:\Extra Knowledge\Python\developer_survey_2020/survey_results_public.csv', index_col='Respondent')
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df_schema=pd.read_csv('D:\Extra Knowledge\Python\developer_survey_2020/survey_results_schema.csv')
df_schema.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?
# 3         Age  What is your age (in years)? If you prefer not...
# 4  Age1stCode  At what age did you write your first line of c...

# %%
df_schema.set_index('Column')
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
df_schema.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?
# 3         Age  What is your age (in years)? If you prefer not...
# 4  Age1stCode  At what age did you write your first line of c...

# %%
df_schema=pd.read_csv('D:\Extra Knowledge\Python\developer_survey_2020/survey_results_schema.csv', index_col='Column')
df_schema.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8     116000.0
# 9          NaN
# 10     32315.0
# 11     40070.0
# 12     14268.0
# 13     38916.0
# 14     66000.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
#its give us median of developer salary in us dollar
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
#its give us median of which column contain numerical values
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
#for more statistical perspective
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df_schema.loc[['UndergradMajor', 'WebframeDesireNextYear',
       'WebframeWorkedWith']]
# Out:
#                                                              QuestionText
# Column
# UndergradMajor                      What was your primary field of study?
# WebframeDesireNextYear  Which web frameworks have you done extensive d...
# WebframeWorkedWith      Which web frameworks have you done extensive d...

# %%
df['UndergradMajor']
# Out:
# Respondent
# 1        Computer science, computer engineering, or sof...
# 2        Computer science, computer engineering, or sof...
# 3                                                      NaN
# 4        Computer science, computer engineering, or sof...
# 5        Computer science, computer engineering, or sof...
#                                ...
# 64858    Computer science, computer engineering, or sof...
# 64867                                                  NaN
# 64898                                                  NaN
# 64925                                                  NaN
# 65112    Computer science, computer engineering, or sof...
# Name: UndergradMajor, Length: 64461, dtype: object

# %%
df['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   31582
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4754
# Information systems, information technology, or system administration              4071
# A natural science (such as biology, chemistry, physics, etc.)                      2205
# Mathematics or statistics                                                          1849
# Web development or web design                                                      1789
# A business discipline (such as accounting, finance, marketing, etc.)               1375
# A humanities discipline (such as literature, history, philosophy, etc.)            1007
# A social science (such as anthropology, psychology, political science, etc.)        933
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      725
# I never declared a major                                                            453
# ...

# %%
df['Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Kiribati              1
# Grenada               1
# Liechtenstein         1
# Saint Lucia           1
# Lesotho               1
# Name: Country, Length: 183, dtype: int64

# %%
filt=df['Country']=='Bangladesh'
df[filt]
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 575                 I am a developer by profession      Yes  19.0         19
# 614                 I am a developer by profession      Yes   NaN         18
# 747         I am a student who is learning to code      Yes  21.0         15
# 916                 I am a developer by profession      Yes  33.0         24
# 945                 I am a developer by profession      Yes  31.0         24
# ...                                            ...      ...   ...        ...
# 47633                                          NaN      Yes   NaN        NaN
# 51773                                          NaN      Yes   NaN         18
# 55074                                          NaN      Yes  36.0         35
# 58839                                          NaN      Yes   NaN          5
# 63796                                          NaN      Yes   NaN         16
#
# ...

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('Bangladesh')
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 575                 I am a developer by profession      Yes  19.0         19
# 614                 I am a developer by profession      Yes   NaN         18
# 747         I am a student who is learning to code      Yes  21.0         15
# 916                 I am a developer by profession      Yes  33.0         24
# 945                 I am a developer by profession      Yes  31.0         24
# ...                                            ...      ...   ...        ...
# 47633                                          NaN      Yes   NaN        NaN
# 51773                                          NaN      Yes   NaN         18
# 55074                                          NaN      Yes  36.0         35
# 58839                                          NaN      Yes   NaN          5
# 63796                                          NaN      Yes   NaN         16
#
# ...

# %%
filt = df['Country'] == 'Bangladesh'
df.loc[filt]['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering                 326
# A business discipline (such as accounting, finance, marketing, etc.)             23
# Another engineering discipline (such as civil, electrical, mechanical, etc.)     19
# Web development or web design                                                    16
# Mathematics or statistics                                                        11
# A natural science (such as biology, chemistry, physics, etc.)                    10
# A social science (such as anthropology, psychology, political science, etc.)      9
# A humanities discipline (such as literature, history, philosophy, etc.)           9
# Information systems, information technology, or system administration             7
# I never declared a major                                                          2
# Name: UndergradMajor, dtype: int64

# %%
country_grp['UndergradMajor']

# %%
country_grp['UndergradMajor'].value_counts().head(15)
# Out:
# Country      UndergradMajor
# Afghanistan  Computer science, computer engineering, or software engineering                 30
#              Web development or web design                                                    3
#              Another engineering discipline (such as civil, electrical, mechanical, etc.)     2
#              Information systems, information technology, or system administration            2
#              Mathematics or statistics                                                        2
#              A natural science (such as biology, chemistry, physics, etc.)                    1
# Albania      Computer science, computer engineering, or software engineering                 25
#              Web development or web design                                                    4
#              Information systems, information technology, or system administration            3
# ...

# %%
country_grp['UndergradMajor'].value_counts().loc['Bangladesh']
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                 326
# A business discipline (such as accounting, finance, marketing, etc.)             23
# Another engineering discipline (such as civil, electrical, mechanical, etc.)     19
# Web development or web design                                                    16
# Mathematics or statistics                                                        11
# A natural science (such as biology, chemistry, physics, etc.)                    10
# A humanities discipline (such as literature, history, philosophy, etc.)           9
# A social science (such as anthropology, psychology, political science, etc.)      9
# Information systems, information technology, or system administration             7
# I never declared a major                                                          2
# Name: UndergradMajor, dtype: int64

# %%
country_grp['UndergradMajor'].value_counts(normalize=True).loc['Bangladesh']
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                 0.754630
# A business discipline (such as accounting, finance, marketing, etc.)            0.053241
# Another engineering discipline (such as civil, electrical, mechanical, etc.)    0.043981
# Web development or web design                                                   0.037037
# Mathematics or statistics                                                       0.025463
# A natural science (such as biology, chemistry, physics, etc.)                   0.023148
# A humanities discipline (such as literature, history, philosophy, etc.)         0.020833
# A social science (such as anthropology, psychology, political science, etc.)    0.020833
# Information systems, information technology, or system administration           0.016204
# I never declared a major                                                        0.004630
# Name: UndergradMajor, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10056.0

# %%
country_grp['ConvertedComp'].median().loc['Bangladesh']
# Out:
# 7068.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Bangladesh']
# Out:
# median     7068.000000
# mean      21586.559783
# Name: Bangladesh, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt].head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
#
#            CompFreq   CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7           Monthly         NaN            NaN   India  United States dollar
# 22          Monthly         NaN            NaN   India          Indian rupee
# 58              NaN         NaN            NaN   India          Indian rupee
# 63              NaN         NaN            NaN   India                   NaN
# 149          Yearly  21000000.0       293196.0   India          Indian rupee
#
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].head()
# Out:
# Respondent
# 7                            C#;HTML/CSS;PHP
# 22                               Java;Python
# 58              C#;JavaScript;SQL;TypeScript
# 63     C;C++;HTML/CSS;Java;JavaScript;Python
# 149           Bash/Shell/PowerShell;C++;Perl
# Name: LanguageWorkedWith, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
# this return pandas.core.groupby.generic.SeriesGroupBy str.contains 
#only apply pandas.core.series.Series
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-f3ed51540665> in <module>
#       1 # this return pandas.core.groupby.generic.SeriesGroupBy str.contains
#       2 #only apply pandas.core.series.Series
# ----> 3 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
type(country_grp['LanguageWorkedWith'])
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
filt = df['Country'] == 'India'
type(df.loc[filt]['LanguageWorkedWith'])
# Out:
# pandas.core.series.Series

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['Bangladesh']
# Out:
# 179

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Kiribati              1
# Grenada               1
# Liechtenstein         1
# Saint Lucia           1
# Lesotho               1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# ...                 ...                 ...
# Kiribati              1                   0
# Grenada               1                   0
# Liechtenstein         1                   0
# Saint Lucia           1                   1
# Lesotho               1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                 NumRespondents  NumKnowsPython
# United States            12469            5964
# India                     8403            2670
# United Kingdom            3896            1621
# Germany                   3890            1712
# Canada                    2191            1011
# ...                        ...             ...
# Kiribati                     1               0
# Grenada                      1               0
# Liechtenstein                1               0
# Saint Lucia                  1               1
# Lesotho                      1               0
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                 NumRespondents  NumKnowsPython  PctKnowsPython
# United States            12469            5964       47.830620
# India                     8403            2670       31.774366
# United Kingdom            3896            1621       41.606776
# Germany                   3890            1712       44.010283
# Canada                    2191            1011       46.143314
# ...                        ...             ...             ...
# Kiribati                     1               0        0.000000
# Grenada                      1               0        0.000000
# Liechtenstein                1               0        0.000000
# Saint Lucia                  1               1      100.000000
# Lesotho                      1               0        0.000000
#
# [183 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(10)
# Out:
#                                     NumRespondents  NumKnowsPython  \
# Saint Lucia                                      1               1
# Micronesia, Federated States of...               1               1
# Gabon                                            1               1
# Montenegro                                      13               9
# Brunei Darussalam                                3               2
# Guyana                                           5               3
# Swaziland                                        7               4
# Iceland                                         53              28
# Finland                                        349             183
# Uganda                                          81              42
#
#                                     PctKnowsPython
# Saint Lucia                             100.000000
# Micronesia, Federated States of...      100.000000
# Gabon                                   100.000000
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    297.000000
# NumKnowsPython    132.000000
# PctKnowsPython     44.444444
# Name: Japan, dtype: float64
