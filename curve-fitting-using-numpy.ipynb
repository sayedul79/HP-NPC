# %% [markdown]
# # Course No. EEE-353 (Measurement and Instrumentation)
# ## Assignment-1 (17 Batch)
#
# #### Name : MD. SAYEDUL
# #### ID : 1702079

# %% [markdown]
# ### The input-output relationship of a thermometer reading and Resistance
# | Temparature($\theta$ in $^{\circ}$C) | Resistance(R in $\Omega$) |
# | :-: | :-: |
# | 90 | 279 |
# | 95 | 285 |
# | 100 | 291 |
# | 105 | 299 |
# | 110 | 308 |
# | 115 | 317 |
# | 120 | 325 |
# | 125 | 333 |
# | 130 | 343 |

# %% [markdown]
# ### Import library

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook
#%matplotlib inline
print('All essential libraries are imported')
# Out:
# All essential libraries are imported

# %% [markdown]
# ### Find the value of a, b, c, d and e for which the following relationship is satisfied $$R=a \theta^{4}+b \theta^{3}+c \theta^{2}+d \theta+e$$

# %%
T=np.array([90, 95, 100, 105, 110, 115,
           120, 125, 130])
R=np.array([279, 285, 291, 299, 308, 317,
           325, 333, 343])
print("Temparature(Celcius) :", T)
print('Resistance(Ohm) :', R)
# Out:
# Temparature(Celcius) : [ 90  95 100 105 110 115 120 125 130]
# Resistance(Ohm) : [279 285 291 299 308 317 325 333 343]

# %%
curve4=np.polyfit(T, R, 4)
curve4
# Out:
# array([ 1.95804196e-05, -8.91168091e-03,  1.51915307e+00, -1.13258405e+02,
#         3.37930381e+03])

# %%
poly4=np.poly1d(curve4)
print(poly4)
# Out:
#            4            3         2
# 1.958e-05 x - 0.008912 x + 1.519 x - 113.3 x + 3379

# %%
plt.figure(1)

x=np.linspace(0, 200, 200)
plt.scatter(T, R)
plt.plot(x, poly4(x), 'r')

plt.title(
    "Curve fitting on $a \Theta^{4}+b \Theta^{3}+c \Theta^{2}+d \Theta+e$")
plt.xlabel('Temparature($\Theta$ in $^{\circ}$C)')
plt.ylabel('Resistance(R in $\Omega$)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Resistance(R in $\\Omega$)')

# %% [markdown]
# ### Find the value of f, g, h and k for which the following relationship is satisfied $$R=f \theta^{3}+g \theta^{2}+h \theta+k $$

# %%
curve3=np.polyfit(T, R, 3)
curve3
# Out:
# array([-2.96296296e-04,  1.05656566e-01, -1.07814815e+01,  6.09464646e+02])

# %%
poly3=np.poly1d(curve3)
print(poly3)
# Out:
#             3          2
# -0.0002963 x + 0.1057 x - 10.78 x + 609.5

# %%
plt.figure(2)

x=np.linspace(0, 200, 200)
plt.scatter(T, R)
plt.plot(x, poly3(x), 'r')

plt.title(
    "Curve fitting on $f \Theta^{3}+g \Theta^{2}+h \Theta+k$")
plt.xlabel('Temparature($\Theta$ in $^{\circ}C$)')
plt.ylabel('Resistance(R in $\Omega$)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Resistance(R in $\\Omega$)')

# %% [markdown]
# ### Find the value of m and n for which the following relationship is satisfied $$R=m \theta+n $$

# %%
curve1=np.polyfit(T, R, 1)
curve1
# Out:
# array([  1.62      , 130.68888889])

# %%
poly1=np.poly1d(curve1)
print(poly1)
# Out:
#
# 1.62 x + 130.7

# %%
plt.figure()

x=np.linspace(0, 200, 200)
plt.scatter(T, R)
plt.plot(x, poly1(x), 'r')

plt.title(
    "Curve fitting on $m \Theta+n$")
plt.xlabel('Temparature($\Theta$ in $^{\circ}$C)')
plt.ylabel('Resistance(R in $\Omega$)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Resistance(R in $\\Omega$)')
