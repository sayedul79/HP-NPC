# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.3.2

# %%
print(matplotlib.get_backend())
# Out:
# module://ipykernel.pylab.backend_inline

# %%
matplotlib.use('nbagg')
print(matplotlib.get_backend())
# Out:
# nbAgg

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig = plt.figure(facecolor=(1, 0, 0, .1))

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1120">

# %%
fig = plt.figure(figsize=plt.figaspect(0.5), facecolor=(1, 0, 0, .1))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="318.2857142857143">

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.set_xlim(0.5,4)
ax.set_ylim(-2,8)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_title('An axes example')
# Out:
# Text(0.5, 1.0, 'An axes example')

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes=plt.subplots(nrows=2, ncols=2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes=plt.subplots(nrows=2, ncols=2, sharex=True)
axes[0,0].set(title='Upper left')
axes[0,1].set(title='Upper right')
axes[1,0].set(title='Lower left')
axes[1,1].set(title='Lower right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes=plt.subplots(nrows=2, ncols=2, sharex=True)
axes[0,0].set(title='Upper left')
axes[0,1].set(title='Upper right')
axes[1,0].set(title='Lower left')
axes[1,1].set(title='Lower right')
for ax in axes.flat:
    ax.set(xticks=[], yticks=[])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(axes.shape)
# Out:
# (2, 2)

# %%
print(axes.ndim)
# Out:
# 2

# %%
fig, axes=plt.subplots(nrows=3)
x=np.linspace(0,10,100)
y1, y2, y3 =np.cos(x), np.cos(x+1), np.cos(x+2)
names=['cos(x)', 'cos(x+1)', 'cos(x+2)']
for ax, y, name in zip(axes.flat, [y1, y2, y3], names):
    ax.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
